# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5995.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (86).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5914.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2467.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2138.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_914.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3199.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2738.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_143.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1933.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3645.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_890.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (29).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2664.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3681.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_650.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1231.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5173.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2787.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1719.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6323.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1785.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_485.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5825.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_123.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_184.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6307.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2227.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1585.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_88.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6225.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1545.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3622.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5430.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1533.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3528.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1763.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6297.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1349.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_223.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1805.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1232.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1626.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2437.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1197.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1559.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2525.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5798.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3064.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_907.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3001.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (92).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_960.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5212.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_332.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1125.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2624.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3428.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (65).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2324.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_77.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3422.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5784.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2425.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2266.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (55).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1034.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5312.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6018.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_71.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (104).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (103).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3899.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (106).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3160.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5406.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (54).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_274.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1100.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5621.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1319.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5880.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3319.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2654.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2459.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6183.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2457.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5725.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5563.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6291.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3689.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_570.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_641.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2212.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5670.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (69).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5603.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3906.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1962.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_341.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3665.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3145.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_586.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1603.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1859.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (60).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_296.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2435.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_517.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2732.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1687.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_456.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3818.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (89).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_731.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3529.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5801.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2125.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2921.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (87).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2677.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2769.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_935.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6134.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2030.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3852.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1907.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2816.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1436.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1571.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1457.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3129.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1722.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2713.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_521.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2894.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3675.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5501.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2563.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2553.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1748.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (82).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3413.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2814.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2903.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5988.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1844.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3370.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5346.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3759.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2426.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_970.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1896.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_441.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (49).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1187.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3826.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5480.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3323.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5829.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5285.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_48.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (72).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2228.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_652.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (48).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_916.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2397.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1393.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5682.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2682.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1707.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2498.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5808.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1160.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3619.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5555.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2460.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (53).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2977.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_494.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1701.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_700.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3863.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2679.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3483.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3465.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1415.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1313.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5726.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_241.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5666.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (47).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6141.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5632.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (68).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2086.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5252.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6074.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2845.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5751.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2635.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_898.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_600.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3875.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1577.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_764.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1146.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2916.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3584.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1698.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_805.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_133.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_190.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2033.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1845.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5316.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5428.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_0.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5442.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_199.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_450.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5349.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_863.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (27).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2611.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2424.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1159.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_766.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1214.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2492.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (88).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1071.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2533.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3338.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1799.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5530.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3882.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_387.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_346.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2638.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1130.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_999.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3269.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2116.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5225.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3596.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5558.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_316.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1040.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_127.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_305.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_636.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3867.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1405.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3324.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1721.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1230.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1342.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3080.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3292.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_353.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_709.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3861.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1012.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1570.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3883.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (19).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1113.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6136.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5498.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1392.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1133.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3604.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3560.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5653.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3085.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (101).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_620.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3143.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5865.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_327.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3793.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6321.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3230.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_455.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (73).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_236.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3550.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_712.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_338.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_205.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_192.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_967.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2458.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1338.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5463.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6206.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3808.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (31).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (57).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1294.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6273.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5618.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5507.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (102).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6168.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_607.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_782.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3114.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_284.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (76).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5816.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2872.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1553.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1930.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2996.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6127.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1508.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2034.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1964.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_231.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_825.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (26).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3101.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1239.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3631.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1580.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2656.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (58).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5662.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3207.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5329.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5332.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_614.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_873.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5185.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1819.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1161.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_482.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2517.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (84).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5723.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (32).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1768.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1966.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2910.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2215.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1482.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5356.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5434.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2881.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3847.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5992.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5789.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_727.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_117.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3382.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1814.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1860.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1303.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3898.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_92.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2149.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_638.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3132.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3154.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3909.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1352.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (28).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2482.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5836.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (80).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (100).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2172.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_240.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_85.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5318.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2990.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_543.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5689.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (56).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_812.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_7.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2774.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (98).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_556.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5375.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3533.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5930.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6040.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (74).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1018.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2961.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3320.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_366.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_818.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3761.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3688.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (91).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5326.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3639.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2696.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_942.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3586.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5461.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5787.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1199.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2798.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1973.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3510.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (52).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3509.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3466.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5416.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1649.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3542.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2193.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1277.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2711.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2176.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2354.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3182.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5963.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1602.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_807.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3502.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (79).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2841.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2586.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_394.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3823.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2011.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_498.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_943.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3312.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6091.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3429.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (64).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_261.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_854.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5775.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_484.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3705.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_990.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (18).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2895.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5418.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1791.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_745.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3112.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_331.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5402.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2025.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3775.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6203.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3853.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5259.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1227.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3817.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_222.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_599.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2017.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5347.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3711.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3397.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (50).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3553.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (67).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3341.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1235.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3718.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_217.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5536.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (51).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_398.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_725.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2558.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (75).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (61).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2322.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3415.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (97).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (20).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3111.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_47.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (70).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (71).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3113.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_129.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3117.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5258.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5547.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2241.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2944.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_164.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3180.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_230.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1782.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (95).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (90).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1275.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5800.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3438.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3069.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_505.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1411.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (105).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_131.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5938.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5586.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3364.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6157.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (30).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2822.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1460.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (25).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3635.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5275.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3777.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_401.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3331.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (93).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1965.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3260.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3558.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6198.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2063.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3100.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3870.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1055.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6239.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1353.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5602.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2838.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5907.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (62).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_302.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2821.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2522.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3461.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5828.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_671.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1333.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5771.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6005.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5748.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_529.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (63).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3328.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_162.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5768.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6017.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (96).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1998.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1827.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3854.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6205.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1094.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (77).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_324.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (81).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2529.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_629.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1867.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (21).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5337.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3356.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5552.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5383.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1401.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (23).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_667.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5303.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2904.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_35.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_370.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_842.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (78).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_695.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (94).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1060.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3236.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3128.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (22).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1510.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2383.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2122.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1119.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6072.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1838.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3456.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1293.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (59).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_918.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_18.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2327.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_878.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2292.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5934.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2651.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5187.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3376.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (83).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (66).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3301.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (46).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (99).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6269.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (85).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_141.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5701.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1287.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1941.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_6226.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_497.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3841.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_3253.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1632.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2440.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5903.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5781.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1596.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/Leaf_scald (24).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_321.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_2330.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_1924.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Leaf scald/aug_0_5551.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Sheath Blight/Sheath_Blight (60).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Sheath Blight/IMG_20231014_173759.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Sheath Blight/IMG_20231018_143318.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Sheath Blight/aug_0_9839.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Sheath Blight/aug_0_9584.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Sheath Blight/Sheath_Blight (121).jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Sheath Blight/IMG_20231014_170958.jpg
# ...
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_413.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3705.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_471.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1791.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3112.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4013.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4899.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_716.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4211.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5923.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4545.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4219.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_172818.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3397.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173602.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5989.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3307.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3347.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4932.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6507.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_172843.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3107.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3595.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5180.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5958.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4093.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5585.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_741.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1166.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_129.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_747.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4832.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5441.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_334.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3840.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231018_143622.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3437.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173606.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3125.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_230.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4797.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173137_1.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_172852.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231018_143030.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5271.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5800.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_742.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4610.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1726.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3167.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173621.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1226.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5328.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3683.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5617.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6447.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_271.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3783.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5361.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_616.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5529.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173342.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1460.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_59.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5222.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3260.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3907.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6198.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3972.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4250.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3629.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3100.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4183.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_722.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6239.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_833.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5602.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4179.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5960.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1779.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1238.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5803.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3753.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3888.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1254.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1006.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3029.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1622.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4146.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1481.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3096.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_39.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4261.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5589.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3393.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4494.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6414.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3470.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173521.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231018_143623.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_342.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6009.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3151.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_183.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4848.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5966.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6519.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5985.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173630.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3281.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5038.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6090.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6445.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5756.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5070.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231018_143024.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5050.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_14.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3939.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3358.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5201.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5858.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3226.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4026.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3634.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3731.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_663.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1185.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_370.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4585.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3993.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_2948.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_842.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_172840.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3128.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4116.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_911.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5221.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5853.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1838.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_219.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1773.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_172849.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3271.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5661.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173626.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173530.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173255.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_172838.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4449.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4829.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4330.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6230.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5237.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3592.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6024.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4765.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1751.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3868.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_789.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3217.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6052.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_178.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173549.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3229.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_172951.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5223.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4476.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4912.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_1614.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3068.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4078.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_917.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_6368.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4223.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3608.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_173003.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231018_143859_1.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_3186.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_148.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_5344.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/IMG_20231014_172830.jpg
# /kaggle/input/rice-disease-dataset/Rice_Leaf_AUG/Bacterial Leaf Blight/aug_0_4451.jpg

# %%
##### import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision.models import mobilenet_v2
import numpy as np
import cv2
from PIL import Image
import os
import json
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List, Tuple, Dict, Optional
import warnings
import glob
import random
from collections import defaultdict
warnings.filterwarnings('ignore')

class DepthwiseSeparableConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=0, bias=False):
        super(DepthwiseSeparableConv2d, self).__init__()
        
        self.depthwise = nn.Conv2d(
            in_channels, in_channels, kernel_size, 
            stride=stride, padding=padding, groups=in_channels, bias=bias
        )
        
        self.pointwise = nn.Conv2d(in_channels, out_channels, 1, bias=bias)
        
    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        return x

class ModifiedInceptionModule(nn.Module):
    """
    Modified Inception (M-Inception) module with depth-wise separable convolutions
    Replaces standard convolutions with DSC to reduce parameters
    """
    def __init__(self, in_channels, branch1_out, branch2_reduce, branch2_out, 
                 branch3_reduce, branch3_out, branch4_out):
        super(ModifiedInceptionModule, self).__init__()
        
        # Branch 1: 1x1 conv
        self.branch1 = nn.Sequential(
            nn.Conv2d(in_channels, branch1_out, 1),
            nn.BatchNorm2d(branch1_out),
            nn.ReLU(inplace=True)
        )
        
        # Branch 2: 1x1 conv -> 3x3 DSC
        self.branch2 = nn.Sequential(
            nn.Conv2d(in_channels, branch2_reduce, 1),
            nn.BatchNorm2d(branch2_reduce),
            nn.ReLU(inplace=True),
            DepthwiseSeparableConv2d(branch2_reduce, branch2_out, 3, padding=1),
            nn.BatchNorm2d(branch2_out),
            nn.ReLU(inplace=True)
        )
        
        # Branch 3: 1x1 conv -> two 3x3 DSC (replacing 5x5)
        self.branch3 = nn.Sequential(
            nn.Conv2d(in_channels, branch3_reduce, 1),
            nn.BatchNorm2d(branch3_reduce),
            nn.ReLU(inplace=True),
            DepthwiseSeparableConv2d(branch3_reduce, branch3_reduce, 3, padding=1),
            nn.BatchNorm2d(branch3_reduce),
            nn.ReLU(inplace=True),
            DepthwiseSeparableConv2d(branch3_reduce, branch3_out, 3, padding=1),
            nn.BatchNorm2d(branch3_out),
            nn.ReLU(inplace=True)
        )
        
        # Branch 4: 3x3 max pool -> 1x1 conv
        self.branch4 = nn.Sequential(
            nn.MaxPool2d(3, stride=1, padding=1),
            nn.Conv2d(in_channels, branch4_out, 1),
            nn.BatchNorm2d(branch4_out),
            nn.ReLU(inplace=True)
        )
        
    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)
        
        # Concatenate along channel dimension
        outputs = torch.cat([branch1, branch2, branch3, branch4], 1)
        return outputs

class MobIncNet(nn.Module):
    """
    MobInc-Net: Lightweight network combining MobileNet with Modified Inception
    """
    def __init__(self, num_classes=12, pretrained=True):
        super(MobIncNet, self).__init__()
        
        # Load pre-trained MobileNetV2 backbone
        mobilenet = mobilenet_v2(pretrained=pretrained)
        
        # Extract features from MobileNet (remove classifier)
        self.backbone = nn.Sequential(*list(mobilenet.children())[:-1])
        
        # Get the number of features from MobileNet
        backbone_out_features = 1280  # MobileNetV2 output features
        
        # Modified Inception module with 512 filters
        self.m_inception = ModifiedInceptionModule(
            in_channels=backbone_out_features,
            branch1_out=128,      # 1x1 branch
            branch2_reduce=96,    # 3x3 reduce
            branch2_out=128,      # 3x3 output
            branch3_reduce=16,    # 5x5 reduce (using two 3x3)
            branch3_out=32,       # 5x5 output
            branch4_out=64        # pool proj
        )
        
        # Calculate total output channels from M-Inception
        inception_out_features = 128 + 128 + 32 + 64  # 352
        
        # Global Average Pooling
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        
        # Classifier head
        self.classifier = nn.Sequential(
            nn.Dropout(0.2),
            nn.Linear(inception_out_features, num_classes)
        )
        
    def forward(self, x):
        # Extract features using MobileNet backbone
        x = self.backbone(x)
        
        # Apply Modified Inception module
        x = self.m_inception(x)
        
        # Global Average Pooling
        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)
        
        # Classification
        x = self.classifier(x)
        return x

class FocalLoss(nn.Module):
    """
    Improved Focal Loss for multi-class classification
    Addresses class imbalance and focuses on hard examples
    """
    def __init__(self, alpha=1.0, gamma=2.0, weight=None, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.weight = weight
        self.reduction = reduction
        
    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, weight=self.weight, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1-pt)**self.gamma * ce_loss
        
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

class RiceDiseaseDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform
        
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        label = self.labels[idx]
        
        try:
            image = Image.open(image_path).convert('RGB')
        except:
            image = Image.new('RGB', (224, 224), color='white')
            
        if self.transform:
            image = self.transform(image)
            
        return image, label

class RiceDatasetLoader:
    def __init__(self, dataset_path="/kaggle/input/rice-disease-dataset/Rice_Leaf_AUG"):
        self.dataset_path = dataset_path
        self.class_names = [
            'Bacterial Leaf Blight',
            'Brown Spot', 
            'Healthy Rice Leaf',
            'Leaf Blast',
            'Leaf scald',
            'Sheath Blight'
        ]
        self.class_to_idx = {name: idx for idx, name in enumerate(self.class_names)}
        
    def load_dataset(self, train_split=0.7, val_split=0.15, test_split=0.15):
        all_image_paths = []
        all_labels = []
        
        for class_name in self.class_names:
            class_path = os.path.join(self.dataset_path, class_name)
            if os.path.exists(class_path):
                image_files = glob.glob(os.path.join(class_path, "*.*"))
                image_files = [f for f in image_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
                
                class_label = self.class_to_idx[class_name]
                all_image_paths.extend(image_files)
                all_labels.extend([class_label] * len(image_files))
        
        data_by_class = defaultdict(list)
        for path, label in zip(all_image_paths, all_labels):
            data_by_class[label].append(path)
        
        train_paths, val_paths, test_paths = [], [], []
        train_labels, val_labels, test_labels = [], [], []
        
        for class_idx, paths in data_by_class.items():
            random.shuffle(paths)
            n_total = len(paths)
            n_train = int(n_total * train_split)
            n_val = int(n_total * val_split)
            
            train_paths.extend(paths[:n_train])
            val_paths.extend(paths[n_train:n_train+n_val])
            test_paths.extend(paths[n_train+n_val:])
            
            train_labels.extend([class_idx] * n_train)
            val_labels.extend([class_idx] * n_val)
            test_labels.extend([class_idx] * (n_total - n_train - n_val))
        
        return {
            'train': (train_paths, train_labels),
            'val': (val_paths, val_labels),
            'test': (test_paths, test_labels)
        }
    
    def create_dataloaders(self, batch_size=64):
        data_splits = self.load_dataset()
        
        train_transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomVerticalFlip(p=0.5),
            transforms.RandomRotation(degrees=(-180, 180)),
            transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
            transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.8, 1.2)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
        
        val_transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
        
        train_dataset = RiceDiseaseDataset(
            data_splits['train'][0], data_splits['train'][1], train_transform
        )
        val_dataset = RiceDiseaseDataset(
            data_splits['val'][0], data_splits['val'][1], val_transform
        )
        test_dataset = RiceDiseaseDataset(
            data_splits['test'][0], data_splits['test'][1], val_transform
        )
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
        
        print(f"Train samples: {len(train_dataset)}")
        print(f"Val samples: {len(val_dataset)}")
        print(f"Test samples: {len(test_dataset)}")
        print(f"Classes: {self.class_names}")
        
        return train_loader, val_loader, test_loader

class DataAugmentation:
    """
    Data augmentation techniques for training
    """
    @staticmethod
    def get_train_transforms():
        return transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomVerticalFlip(p=0.5),
            transforms.RandomRotation(degrees=(-180, 180)),
            transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
            transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.8, 1.2)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
    
    @staticmethod
    def get_val_transforms():
        return transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

class TwoStageTrainer:
    """
    Two-stage transfer learning trainer
    """
    def __init__(self, model, device, num_classes):
        self.model = model.to(device)
        self.device = device
        self.num_classes = num_classes
        
    def stage_one_training(self, train_loader, val_loader, epochs=10, lr=5e-4):
        """
        Stage 1: Freeze backbone, train only new layers
        """
        print("Stage 1: Training new layers only...")
        
        # Freeze backbone parameters
        for param in self.model.backbone.parameters():
            param.requires_grad = False
            
        # Only optimize new layers
        optimizer = optim.Adam(
            filter(lambda p: p.requires_grad, self.model.parameters()),
            lr=lr, weight_decay=1e-4
        )
        
        # Calculate class weights for focal loss
        class_weights = self._calculate_class_weights(train_loader)
        criterion = FocalLoss(gamma=2.0, weight=class_weights)
        
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        
        best_val_acc = 0.0
        train_losses, val_losses, val_accuracies = [], [], []
        
        for epoch in range(epochs):
            # Training
            self.model.train()
            train_loss = 0.0
            
            for batch_idx, (data, targets) in enumerate(train_loader):
                data, targets = data.to(self.device), targets.to(self.device)
                
                optimizer.zero_grad()
                outputs = self.model(data)
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                
                train_loss += loss.item()
                
                if batch_idx % 10 == 0:
                    print(f'Epoch {epoch+1}/{epochs}, Batch {batch_idx}, Loss: {loss.item():.4f}')
            
            # Validation
            val_loss, val_acc = self._validate(val_loader, criterion)
            
            train_losses.append(train_loss / len(train_loader))
            val_losses.append(val_loss)
            val_accuracies.append(val_acc)
            
            print(f'Epoch {epoch+1}/{epochs}: Train Loss: {train_loss/len(train_loader):.4f}, '
                  f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')
            
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                torch.save(self.model.state_dict(), 'mobinc_net_stage1.pth')
            
            scheduler.step()
            
        return train_losses, val_losses, val_accuracies
    
    def stage_two_training(self, train_loader, val_loader, epochs=10, lr=1e-4):
        """
        Stage 2: Fine-tune entire network
        """
        print("Stage 2: Fine-tuning entire network...")
        
        # Unfreeze all parameters
        for param in self.model.parameters():
            param.requires_grad = True
            
        # Lower learning rate for fine-tuning
        optimizer = optim.Adam(self.model.parameters(), lr=lr, weight_decay=1e-4)
        
        # Calculate class weights for focal loss
        class_weights = self._calculate_class_weights(train_loader)
        criterion = FocalLoss(gamma=2.0, weight=class_weights)
        
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        
        best_val_acc = 0.0
        train_losses, val_losses, val_accuracies = [], [], []
        
        for epoch in range(epochs):
            # Training
            self.model.train()
            train_loss = 0.0
            
            for batch_idx, (data, targets) in enumerate(train_loader):
                data, targets = data.to(self.device), targets.to(self.device)
                
                optimizer.zero_grad()
                outputs = self.model(data)
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                
                train_loss += loss.item()
                
                if batch_idx % 10 == 0:
                    print(f'Epoch {epoch+1}/{epochs}, Batch {batch_idx}, Loss: {loss.item():.4f}')
            
            # Validation
            val_loss, val_acc = self._validate(val_loader, criterion)
            
            train_losses.append(train_loss / len(train_loader))
            val_losses.append(val_loss)
            val_accuracies.append(val_acc)
            
            print(f'Epoch {epoch+1}/{epochs}: Train Loss: {train_loss/len(train_loader):.4f}, '
                  f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')
            
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                torch.save(self.model.state_dict(), 'mobinc_net_final.pth')
            
            scheduler.step()
            
        return train_losses, val_losses, val_accuracies
    
    def _validate(self, val_loader, criterion):
        """Validation function"""
        self.model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        
        with torch.no_grad():
            for data, targets in val_loader:
                data, targets = data.to(self.device), targets.to(self.device)
                outputs = self.model(data)
                loss = criterion(outputs, targets)
                
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += targets.size(0)
                correct += (predicted == targets).sum().item()
        
        val_acc = correct / total
        return val_loss / len(val_loader), val_acc
    
    def _calculate_class_weights(self, train_loader):
        """Calculate class weights for focal loss"""
        class_counts = torch.zeros(self.num_classes)
        
        for _, targets in train_loader:
            for target in targets:
                class_counts[target] += 1
        
        total_samples = class_counts.sum()
        class_weights = total_samples / (self.num_classes * class_counts)
        
        return class_weights.to(self.device)

class ModelEvaluator:
    """
    Comprehensive model evaluation with multiple metrics
    """
    def __init__(self, model, device, class_names):
        self.model = model
        self.device = device
        self.class_names = class_names
        
    def evaluate(self, test_loader):
        """Comprehensive evaluation"""
        self.model.eval()
        all_predictions = []
        all_targets = []
        all_probabilities = []
        
        with torch.no_grad():
            for data, targets in test_loader:
                data, targets = data.to(self.device), targets.to(self.device)
                outputs = self.model(data)
                probabilities = F.softmax(outputs, dim=1)
                _, predicted = torch.max(outputs, 1)
                
                all_predictions.extend(predicted.cpu().numpy())
                all_targets.extend(targets.cpu().numpy())
                all_probabilities.extend(probabilities.cpu().numpy())
        
        # Calculate metrics
        accuracy = accuracy_score(all_targets, all_predictions)
        recall = recall_score(all_targets, all_predictions, average='macro')
        precision = precision_score(all_targets, all_predictions, average='macro')
        f1 = f1_score(all_targets, all_predictions, average='macro')
        
        # Specificity calculation for each class
        cm = confusion_matrix(all_targets, all_predictions)
        specificity_per_class = []
        
        for i in range(len(self.class_names)):
            tn = np.sum(cm) - (np.sum(cm[i, :]) + np.sum(cm[:, i]) - cm[i, i])
            fp = np.sum(cm[:, i]) - cm[i, i]
            specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
            specificity_per_class.append(specificity)
        
        avg_specificity = np.mean(specificity_per_class)
        
        results = {
            'accuracy': accuracy,
            'recall': recall,
            'precision': precision,
            'f1_score': f1,
            'specificity': avg_specificity,
            'predictions': all_predictions,
            'targets': all_targets,
            'probabilities': all_probabilities,
            'confusion_matrix': cm
        }
        
        return results
    
    def plot_confusion_matrix(self, cm, save_path=None):
        """Plot confusion matrix"""
        plt.figure(figsize=(12, 10))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=self.class_names,
                    yticklabels=self.class_names)
        plt.title('Confusion Matrix')
        plt.xlabel('Predicted Label')
        plt.ylabel('True Label')
        plt.xticks(rotation=45)
        plt.yticks(rotation=0)
        plt.tight_layout()
        
        if save_path:
            plt.savefig(save_path, dpi=300, bbox_inches='tight')
        plt.show()
    
    def plot_roc_curves(self, targets, probabilities, save_path=None):
        """Plot ROC curves for each class"""
        from sklearn.preprocessing import label_binarize
        from sklearn.metrics import roc_curve, auc
        
        # Binarize targets for multi-class ROC
        targets_binary = label_binarize(targets, classes=range(len(self.class_names)))
        probabilities = np.array(probabilities)
        
        plt.figure(figsize=(12, 8))
        
        for i in range(len(self.class_names)):
            fpr, tpr, _ = roc_curve(targets_binary[:, i], probabilities[:, i])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f'{self.class_names[i]} (AUC = {roc_auc:.2f})')
        
        plt.plot([0, 1], [0, 1], 'k--', label='Random')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves for Rice Disease Classification')
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()
        
        if save_path:
            plt.savefig(save_path, dpi=300, bbox_inches='tight')
        plt.show()

class MobIncNetSSD(nn.Module):
    """
    MobInc-Net based SSD for disease detection
    """
    def __init__(self, num_classes=12, num_boxes=[6, 6, 6, 6, 4, 4]):
        super(MobIncNetSSD, self).__init__()
        
        # Base network (MobInc-Net without classifier)
        self.base_net = MobIncNet(num_classes=num_classes)
        # Remove classifier for feature extraction
        self.base_net = nn.Sequential(*list(self.base_net.children())[:-1])
        
        # Auxiliary network for multi-scale detection
        self.aux_convs = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(352, 256, 1),
                nn.ReLU(inplace=True),
                nn.Conv2d(256, 512, 3, stride=2, padding=1),
                nn.ReLU(inplace=True)
            ),
            nn.Sequential(
                nn.Conv2d(512, 128, 1),
                nn.ReLU(inplace=True),
                nn.Conv2d(128, 256, 3, stride=2, padding=1),
                nn.ReLU(inplace=True)
            ),
            nn.Sequential(
                nn.Conv2d(256, 128, 1),
                nn.ReLU(inplace=True),
                nn.Conv2d(128, 256, 3),
                nn.ReLU(inplace=True)
            ),
            nn.Sequential(
                nn.Conv2d(256, 64, 1),
                nn.ReLU(inplace=True),
                nn.Conv2d(64, 128, 3),
                nn.ReLU(inplace=True)
            )
        ])
        
        # Prediction layers
        self.loc_layers = nn.ModuleList()
        self.conf_layers = nn.ModuleList()
        
        source_channels = [352, 512, 256, 256, 128]
        
        for i, (channels, boxes) in enumerate(zip(source_channels, num_boxes)):
            self.loc_layers.append(nn.Conv2d(channels, boxes * 4, 3, padding=1))
            self.conf_layers.append(nn.Conv2d(channels, boxes * num_classes, 3, padding=1))
    
    def forward(self, x):
        sources = []
        loc_preds = []
        conf_preds = []
        
        # Base network feature extraction
        x = self.base_net[0](x)  # backbone
        x = self.base_net[1](x)  # m_inception
        x = self.base_net[2](x)  # global_avg_pool
        sources.append(x)
        
        # Auxiliary network
        for aux_conv in self.aux_convs:
            x = aux_conv(x)
            sources.append(x)
        
        # Predictions
        for i, (source, loc_layer, conf_layer) in enumerate(zip(sources, self.loc_layers, self.conf_layers)):
            loc_pred = loc_layer(source)
            conf_pred = conf_layer(source)
            
            # Reshape predictions
            loc_pred = loc_pred.permute(0, 2, 3, 1).contiguous()
            conf_pred = conf_pred.permute(0, 2, 3, 1).contiguous()
            
            loc_preds.append(loc_pred.view(loc_pred.size(0), -1))
            conf_preds.append(conf_pred.view(conf_pred.size(0), -1))
        
        # Concatenate predictions
        loc = torch.cat(loc_preds, 1)
        conf = torch.cat(conf_preds, 1)
        
        return loc, conf

class RiceDiseaseRecognitionSystem:
    """
    Complete system for rice disease recognition and detection
    """
    def __init__(self, device='cuda' if torch.cuda.is_available() else 'cpu'):
        self.device = device
        self.class_names = [
            'Bacterial Leaf Blight',
            'Brown Spot', 
            'Healthy Rice Leaf',
            'Leaf Blast',
            'Leaf scald',
            'Sheath Blight'
        ]
        self.num_classes = len(self.class_names)
        
        # Initialize models
        self.classification_model = MobIncNet(num_classes=self.num_classes)
        self.detection_model = MobIncNetSSD(num_classes=self.num_classes)
        
        print(f"Using device: {self.device}")
        print(f"Number of classes: {self.num_classes}")
        
    def train_classification_model(self, batch_size=64, stage1_epochs=10, stage2_epochs=10):
        train_loader = self._prepare_dataloader('train', batch_size)
        val_loader = self._prepare_dataloader('val', batch_size)
        
        trainer = TwoStageTrainer(self.classification_model, self.device, self.num_classes)
        
        stage1_results = trainer.stage_one_training(train_loader, val_loader, stage1_epochs)
        
        stage2_results = trainer.stage_two_training(train_loader, val_loader, stage2_epochs)
        
        return stage1_results, stage2_results
    
    def evaluate_model(self, model_path=None):
        if model_path:
            self.classification_model.load_state_dict(torch.load(model_path, map_location=self.device))
        
        test_loader = self._prepare_dataloader('test', batch_size=32)
        
        evaluator = ModelEvaluator(self.classification_model, self.device, self.class_names)
        results = evaluator.evaluate(test_loader)
        
        print("\n" + "="*50)
        print("MODEL EVALUATION RESULTS")
        print("="*50)
        print(f"Accuracy: {results['accuracy']:.4f}")
        print(f"Recall: {results['recall']:.4f}")
        print(f"Precision: {results['precision']:.4f}")
        print(f"F1-Score: {results['f1_score']:.4f}")
        print(f"Specificity: {results['specificity']:.4f}")
        
        evaluator.plot_confusion_matrix(results['confusion_matrix'])
        evaluator.plot_roc_curves(results['targets'], results['probabilities'])
        
        return results
    
    def predict_single_image(self, image_path, model_path=None):
        """
        Predict disease for a single image
        """
        if model_path:
            self.classification_model.load_state_dict(torch.load(model_path, map_location=self.device))
        
        self.classification_model.eval()
        
        # Load and preprocess image
        transform = DataAugmentation.get_val_transforms()
        image = Image.open(image_path).convert('RGB')
        image_tensor = transform(image).unsqueeze(0).to(self.device)
        
        with torch.no_grad():
            outputs = self.classification_model(image_tensor)
            probabilities = F.softmax(outputs, dim=1)
            _, predicted = torch.max(outputs, 1)
            
            predicted_class = self.class_names[predicted.item()]
            confidence = probabilities[0][predicted.item()].item()
            
        return predicted_class, confidence, probabilities[0].cpu().numpy()
    
    def _prepare_dataloader(self, data_type='train', batch_size=64):
        if not hasattr(self, 'data_loader'):
            self.data_loader = RiceDatasetLoader()
            
        if data_type == 'train':
            train_loader, _, _ = self.data_loader.create_dataloaders(batch_size)
            return train_loader
        elif data_type == 'val':
            _, val_loader, _ = self.data_loader.create_dataloaders(batch_size)
            return val_loader
        else:
            _, _, test_loader = self.data_loader.create_dataloaders(batch_size)
            return test_loader
    
    def get_model_parameters(self):
        """
        Get model parameter count and size
        """
        total_params = sum(p.numel() for p in self.classification_model.parameters())
        trainable_params = sum(p.numel() for p in self.classification_model.parameters() if p.requires_grad)
        
        # Model size estimation
        param_size = 0
        for param in self.classification_model.parameters():
            param_size += param.nelement() * param.element_size()
        
        buffer_size = 0
        for buffer in self.classification_model.buffers():
            buffer_size += buffer.nelement() * buffer.element_size()
        
        model_size_mb = (param_size + buffer_size) / 1024 / 1024
        
        print(f"Total parameters: {total_params:,}")
        print(f"Trainable parameters: {trainable_params:,}")
        print(f"Model size: {model_size_mb:.2f} MB")
        
        return total_params, trainable_params, model_size_mb

def demo_usage():
    print("MobInc-Net Rice Disease Recognition System Demo")
    print("="*50)
    
    system = RiceDiseaseRecognitionSystem()
    
    print("\nModel Architecture Information:")
    system.get_model_parameters()
    
    print("\nTraining the model:")
    stage1_results, stage2_results = system.train_classification_model(
        batch_size=64,
        stage1_epochs=10,
        stage2_epochs=10
    )
    
    print("\nEvaluating the model:")
    results = system.evaluate_model()
    
    return system, results

def train_and_evaluate_mobinc_net():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")
    
    data_loader = RiceDatasetLoader()
    train_loader, val_loader, test_loader = data_loader.create_dataloaders(batch_size=64)
    
    model = MobIncNet(num_classes=len(data_loader.class_names))
    model = model.to(device)
    
    trainer = TwoStageTrainer(model, device, len(data_loader.class_names))
    
    print("Starting Stage 1 Training...")
    stage1_results = trainer.stage_one_training(train_loader, val_loader, epochs=10)
    
    print("Starting Stage 2 Training...")
    stage2_results = trainer.stage_two_training(train_loader, val_loader, epochs=10)
    
    print("Evaluating model...")
    evaluator = ModelEvaluator(model, device, data_loader.class_names)
    results = evaluator.evaluate(test_loader)
    
    print(f"\nFinal Results:")
    print(f"Accuracy: {results['accuracy']:.4f}")
    print(f"Recall: {results['recall']:.4f}")
    print(f"Precision: {results['precision']:.4f}")
    print(f"F1-Score: {results['f1_score']:.4f}")
    print(f"Specificity: {results['specificity']:.4f}")
    
    return model, results

def compare_with_baseline_models():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    data_loader = RiceDatasetLoader()
    _, _, test_loader = data_loader.create_dataloaders(batch_size=32)
    
    comparison = ModelComparison(device)
    comparison.load_comparison_models(len(data_loader.class_names))
    
    print("Comparing models...")
    results = comparison.compare_models(test_loader)
    
    print("\nComparison Results:")
    for model_name, result in results.items():
        print(f"{model_name}: Acc={result['accuracy']:.4f}, Params={result['parameters']:,}")
    
    return results

class DatasetCreator:
    """
    Helper class to create datasets from image directories
    """
    @staticmethod
    def create_dataset_from_directory(root_dir, test_split=0.2, val_split=0.2):
        """
        Create train/val/test splits from directory structure:
        root_dir/
        ├── class1/
        │   ├── image1.jpg
        │   └── image2.jpg
        ├── class2/
        │   ├── image1.jpg
        │   └── image2.jpg
        └── ...
        """
        import random
        from collections import defaultdict
        
        # Collect all image paths and labels
        image_paths = []
        labels = []
        class_to_idx = {}
        
        for class_idx, class_name in enumerate(sorted(os.listdir(root_dir))):
            class_path = os.path.join(root_dir, class_name)
            if os.path.isdir(class_path):
                class_to_idx[class_name] = class_idx
                
                for image_name in os.listdir(class_path):
                    if image_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                        image_paths.append(os.path.join(class_path, image_name))
                        labels.append(class_idx)
        
        # Create stratified splits
        data_by_class = defaultdict(list)
        for path, label in zip(image_paths, labels):
            data_by_class[label].append(path)
        
        train_paths, val_paths, test_paths = [], [], []
        train_labels, val_labels, test_labels = [], [], []
        
        for class_idx, paths in data_by_class.items():
            random.shuffle(paths)
            n_total = len(paths)
            n_test = int(n_total * test_split)
            n_val = int(n_total * val_split)
            n_train = n_total - n_test - n_val
            
            train_paths.extend(paths[:n_train])
            val_paths.extend(paths[n_train:n_train+n_val])
            test_paths.extend(paths[n_train+n_val:])
            
            train_labels.extend([class_idx] * n_train)
            val_labels.extend([class_idx] * n_val)
            test_labels.extend([class_idx] * n_test)
        
        return {
            'train': (train_paths, train_labels),
            'val': (val_paths, val_labels),
            'test': (test_paths, test_labels),
            'class_to_idx': class_to_idx
        }

class ModelComparison:
    """
    Compare MobInc-Net with other lightweight models
    """
    def __init__(self, device):
        self.device = device
        self.models = {}
        
    def load_comparison_models(self, num_classes):
        """Load all comparison models mentioned in the paper"""
        from torchvision.models import mobilenet_v2, efficientnet_b0
        
        # MobileNetV2
        mobilenet = mobilenet_v2(pretrained=True)
        mobilenet.classifier = nn.Linear(mobilenet.last_channel, num_classes)
        self.models['MobileNetV2'] = mobilenet.to(self.device)
        
        # EfficientNet-B0
        efficientnet = efficientnet_b0(pretrained=True)
        efficientnet.classifier = nn.Linear(efficientnet.classifier.in_features, num_classes)
        self.models['EfficientNet-B0'] = efficientnet.to(self.device)
        
        # Add MobInc-Net
        self.models['MobInc-Net'] = MobIncNet(num_classes=num_classes).to(self.device)
        
    def compare_models(self, test_loader):
        """Compare performance of all models"""
        results = {}
        
        for model_name, model in self.models.items():
            print(f"\nEvaluating {model_name}...")
            
            model.eval()
            correct = 0
            total = 0
            
            with torch.no_grad():
                for data, targets in test_loader:
                    data, targets = data.to(self.device), targets.to(self.device)
                    outputs = model(data)
                    _, predicted = torch.max(outputs, 1)
                    total += targets.size(0)
                    correct += (predicted == targets).sum().item()
            
            accuracy = correct / total
            
            # Count parameters
            total_params = sum(p.numel() for p in model.parameters())
            
            results[model_name] = {
                'accuracy': accuracy,
                'parameters': total_params
            }
            
            print(f"{model_name}: Accuracy = {accuracy:.4f}, Parameters = {total_params:,}")
        
        return results

class PlantVillageDataLoader:
    """
    Data loader for PlantVillage dataset
    """
    @staticmethod
    def prepare_plantvillage_data(dataset_path, batch_size=64):
        """
        Prepare PlantVillage dataset loaders
        Assumes dataset structure: dataset_path/class_name/images
        """
        # Data augmentation transforms
        train_transform = DataAugmentation.get_train_transforms()
        val_transform = DataAugmentation.get_val_transforms()
        
        # Create datasets (placeholder implementation)
        # You would use torchvision.datasets.ImageFolder for actual implementation
        
        print("PlantVillage dataset preparation completed")
        print(f"Training samples: 43,444 (80%)")
        print(f"Validation samples: 10,861 (20%)")
        
        return None, None  # Return actual dataloaders in real implementation


def main():
    model, results = train_and_evaluate_mobinc_net()
    
if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Train samples: 2678
# Val samples: 571
# Test samples: 580
# Classes: ['Bacterial Leaf Blight', 'Brown Spot', 'Healthy Rice Leaf', 'Leaf Blast', 'Leaf scald', 'Sheath Blight']
# Starting Stage 1 Training...
# Stage 1: Training new layers only...
# Epoch 1/10, Batch 0, Loss: 1.2621
# Epoch 1/10, Batch 10, Loss: 0.9196
# Epoch 1/10, Batch 20, Loss: 0.6608
# Epoch 1/10, Batch 30, Loss: 0.7501
# Epoch 1/10, Batch 40, Loss: 0.7016
# Epoch 1/10: Train Loss: 0.7871, Val Loss: 0.6585, Val Acc: 0.5814
# Epoch 2/10, Batch 0, Loss: 0.5187
# Epoch 2/10, Batch 10, Loss: 0.6950
# Epoch 2/10, Batch 20, Loss: 0.6736
# Epoch 2/10, Batch 30, Loss: 0.5534
# Epoch 2/10, Batch 40, Loss: 0.5412
# Epoch 2/10: Train Loss: 0.5499, Val Loss: 0.6463, Val Acc: 0.5639
# Epoch 3/10, Batch 0, Loss: 0.4718
# Epoch 3/10, Batch 10, Loss: 0.4738
# Epoch 3/10, Batch 20, Loss: 0.7075
# Epoch 3/10, Batch 30, Loss: 0.5519
# Epoch 3/10, Batch 40, Loss: 0.4888
# Epoch 3/10: Train Loss: 0.4971, Val Loss: 0.4993, Val Acc: 0.6392
# Epoch 4/10, Batch 0, Loss: 0.4730
# Epoch 4/10, Batch 10, Loss: 0.4976
# Epoch 4/10, Batch 20, Loss: 0.3758
# Epoch 4/10, Batch 30, Loss: 0.4827
# Epoch 4/10, Batch 40, Loss: 0.5116
# Epoch 4/10: Train Loss: 0.4789, Val Loss: 0.5290, Val Acc: 0.6340
# Epoch 5/10, Batch 0, Loss: 0.4390
# Epoch 5/10, Batch 10, Loss: 0.5597
# Epoch 5/10, Batch 20, Loss: 0.3715
# Epoch 5/10, Batch 30, Loss: 0.3928
# Epoch 5/10, Batch 40, Loss: 0.3877
# Epoch 5/10: Train Loss: 0.4378, Val Loss: 0.4946, Val Acc: 0.6427
# Epoch 6/10, Batch 0, Loss: 0.3180
# Epoch 6/10, Batch 10, Loss: 0.4256
# Epoch 6/10, Batch 20, Loss: 0.3913
# Epoch 6/10, Batch 30, Loss: 0.4232
# Epoch 6/10, Batch 40, Loss: 0.4661
# Epoch 6/10: Train Loss: 0.4254, Val Loss: 0.4878, Val Acc: 0.6725
# Epoch 7/10, Batch 0, Loss: 0.3746
# Epoch 7/10, Batch 10, Loss: 0.3969
# Epoch 7/10, Batch 20, Loss: 0.5120
# Epoch 7/10, Batch 30, Loss: 0.2570
# Epoch 7/10, Batch 40, Loss: 0.4164
# Epoch 7/10: Train Loss: 0.4067, Val Loss: 0.4202, Val Acc: 0.6953
# Epoch 8/10, Batch 0, Loss: 0.4606
# Epoch 8/10, Batch 10, Loss: 0.3881
# Epoch 8/10, Batch 20, Loss: 0.2621
# Epoch 8/10, Batch 30, Loss: 0.3255
# Epoch 8/10, Batch 40, Loss: 0.2465
# Epoch 8/10: Train Loss: 0.3822, Val Loss: 0.4485, Val Acc: 0.6918
# Epoch 9/10, Batch 0, Loss: 0.3796
# Epoch 9/10, Batch 10, Loss: 0.3807
# Epoch 9/10, Batch 20, Loss: 0.2914
# Epoch 9/10, Batch 30, Loss: 0.3806
# Epoch 9/10, Batch 40, Loss: 0.4213
# Epoch 9/10: Train Loss: 0.3938, Val Loss: 0.4149, Val Acc: 0.7075
# Epoch 10/10, Batch 0, Loss: 0.3709
# Epoch 10/10, Batch 10, Loss: 0.4724
# Epoch 10/10, Batch 20, Loss: 0.2948
# Epoch 10/10, Batch 30, Loss: 0.3081
# Epoch 10/10, Batch 40, Loss: 0.3597
# Epoch 10/10: Train Loss: 0.3751, Val Loss: 0.4063, Val Acc: 0.7093
# Starting Stage 2 Training...
# Stage 2: Fine-tuning entire network...
# Epoch 1/10, Batch 0, Loss: 0.3539
# Epoch 1/10, Batch 10, Loss: 0.4340
# Epoch 1/10, Batch 20, Loss: 0.2606
# Epoch 1/10, Batch 30, Loss: 0.2195
# Epoch 1/10, Batch 40, Loss: 0.3110
# Epoch 1/10: Train Loss: 0.3510, Val Loss: 0.2854, Val Acc: 0.8004
# Epoch 2/10, Batch 0, Loss: 0.2950
# Epoch 2/10, Batch 10, Loss: 0.3325
# Epoch 2/10, Batch 20, Loss: 0.2667
# Epoch 2/10, Batch 30, Loss: 0.2204
# Epoch 2/10, Batch 40, Loss: 0.2978
# Epoch 2/10: Train Loss: 0.2652, Val Loss: 0.2595, Val Acc: 0.7933
# Epoch 3/10, Batch 0, Loss: 0.2815
# Epoch 3/10, Batch 10, Loss: 0.1488
# Epoch 3/10, Batch 20, Loss: 0.1778
# Epoch 3/10, Batch 30, Loss: 0.2272
# Epoch 3/10, Batch 40, Loss: 0.1585
# Epoch 3/10: Train Loss: 0.2207, Val Loss: 0.1808, Val Acc: 0.8564
# Epoch 4/10, Batch 0, Loss: 0.1464
# Epoch 4/10, Batch 10, Loss: 0.1336
# Epoch 4/10, Batch 20, Loss: 0.1315
# Epoch 4/10, Batch 30, Loss: 0.1543
# Epoch 4/10, Batch 40, Loss: 0.1714
# Epoch 4/10: Train Loss: 0.1822, Val Loss: 0.1633, Val Acc: 0.8634
# Epoch 5/10, Batch 0, Loss: 0.1162
# Epoch 5/10, Batch 10, Loss: 0.1935
# Epoch 5/10, Batch 20, Loss: 0.1323
# Epoch 5/10, Batch 30, Loss: 0.2212
# Epoch 5/10, Batch 40, Loss: 0.1994
# Epoch 5/10: Train Loss: 0.1561, Val Loss: 0.1678, Val Acc: 0.8669
# Epoch 6/10, Batch 0, Loss: 0.1159
# Epoch 6/10, Batch 10, Loss: 0.1648
# Epoch 6/10, Batch 20, Loss: 0.1168
# Epoch 6/10, Batch 30, Loss: 0.1930
# Epoch 6/10, Batch 40, Loss: 0.1366
# Epoch 6/10: Train Loss: 0.1383, Val Loss: 0.1363, Val Acc: 0.8949
# Epoch 7/10, Batch 0, Loss: 0.1669
# Epoch 7/10, Batch 10, Loss: 0.1271
# Epoch 7/10, Batch 20, Loss: 0.0779
# Epoch 7/10, Batch 30, Loss: 0.1274
# Epoch 7/10, Batch 40, Loss: 0.1051
# Epoch 7/10: Train Loss: 0.1276, Val Loss: 0.1429, Val Acc: 0.8897
# Epoch 8/10, Batch 0, Loss: 0.0737
# Epoch 8/10, Batch 10, Loss: 0.1715
# Epoch 8/10, Batch 20, Loss: 0.1977
# Epoch 8/10, Batch 30, Loss: 0.1000
# Epoch 8/10, Batch 40, Loss: 0.1754
# Epoch 8/10: Train Loss: 0.1180, Val Loss: 0.1057, Val Acc: 0.9177
# Epoch 9/10, Batch 0, Loss: 0.1081
# Epoch 9/10, Batch 10, Loss: 0.1645
# Epoch 9/10, Batch 20, Loss: 0.0883
# Epoch 9/10, Batch 30, Loss: 0.1498
# Epoch 9/10, Batch 40, Loss: 0.1017
# Epoch 9/10: Train Loss: 0.1035, Val Loss: 0.1012, Val Acc: 0.9264
# Epoch 10/10, Batch 0, Loss: 0.0479
# Epoch 10/10, Batch 10, Loss: 0.0823
# Epoch 10/10, Batch 20, Loss: 0.0914
# Epoch 10/10, Batch 30, Loss: 0.0973
# Epoch 10/10, Batch 40, Loss: 0.1216
# Epoch 10/10: Train Loss: 0.1000, Val Loss: 0.0969, Val Acc: 0.9317
# Evaluating model...
#
# Final Results:
# Accuracy: 0.9379
# Recall: 0.9377
# Precision: 0.9400
# F1-Score: 0.9376
# Specificity: 0.9876
